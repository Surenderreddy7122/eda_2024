# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
data_types=visa_df.dtypes
dict_data_types=dict(data_types)
dict_data_types
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cat_list=visa_df.select_dtypes(include='object').columns
num_list=visa_df.select_dtypes(exclude='object').columns
cat_list
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %%
len(visa_df[visa_df["continent"]=='Asia'])
# Out:
# 16861

# %%
con=visa_df['continent']=='Africa'
len(visa_df[con])
# Out:
# 551

# %%
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    coun=len(visa_df[con])
    print(f'the number of applicants from {i} is: {coun}')
# Out:
# the number of applicants from Asia is: 16861
# the number of applicants from Africa is: 551
# the number of applicants from North America is: 3292
# the number of applicants from Europe is: 3732
# the number of applicants from South America is: 852
# the number of applicants from Oceania is: 192

# %%
continent = visa_df['continent'].unique()

count=[]
for i in visa_df['continent'].unique():
    con=visa_df['continent']==i
    count.append(len(visa_df[con]))
    
cols=['continents','Number of applicants']
continent_df=pd.DataFrame(zip(continent,count),columns=cols)

continent_df.to_csv("continent.csv",index=False)

# %%
pd.read_csv("continent.csv")
# Out:
#       continents  Number of applicants
# 0           Asia                 16861
# 1         Africa                   551
# 2  North America                  3292
# 3         Europe                  3732
# 4  South America                   852
# 5        Oceania                   192

# %%
c_df=visa_df['continent'].value_counts()
c_df
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %% [raw]
# - we craeted a dataframe using dataframe of unique values of a column and its count
# - we created our own way by using for loop
# - the same operation using **value.counts**

# %%
dir(c_df)
# Out:
# ['Africa',
#  'Asia',
#  'Europe',
#  'Oceania',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
c_df.items
# Out:
# <bound method Series.items of Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64>

# %%
keys=c_df.keys()

# %%
type(c_df)
# Out:
# pandas.core.series.Series

# %%
values=c_df.values

# %%
pd.DataFrame(zip(keys,values))
# Out:
#                0      1
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
c_df=visa_df['continent'].value_counts()
keys=c_df.keys()
values=c_df.values
cols=['labels','count']
df1=pd.DataFrame(zip(keys,values),columns=cols)
df1.to_csv('continets1.csv',index=False)

# %%
cat_list[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# - we need to change column name
# - we need to change the file name as column name
# -

# %%
for i in cat_list[1:]:
    print(i)
    c_df = visa_df[i].value_counts()
    keys = c_df.keys()
    values = c_df.values
    cols = ['labels','count']
    df = pd.DataFrame(zip(keys,values),columns=cols)
    path = r"C:\Users\user\Documents\naresh it\EDA\value_counts"
    df.to_csv(f"{path}\\{i}.csv",index=False)
# Out:
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# region_of_employment
# unit_of_wage
# full_time_position
# case_status

# %%
c_df=visa_df['continent'].value_counts(normalize=True)
print(round(c_df*100,2))
# Out:
# Asia             66.17
# Europe           14.65
# North America    12.92
# South America     3.34
# Africa            2.16
# Oceania           0.75
# Name: continent, dtype: float64

# %% [markdown]
# **normalize**
# - relative frequency table
# - will give percentage of table in the column

# %% [markdown]
# **Bar chart**
# - bar chart is the graphical representatiuon of table
# - bar graph is plot between count and class
# - in order to plot bar chart we need 2 columns
#     - catogorical column
#     - numerical column
# - we already created a frequency table continents
#     - here we cols =['continent','number of applicant']
#     - cat column is continent
#     - numerical column is **number of applicant**
# - package:**matplotlib**

# %%
import matplotlib.pyplot as plt
plt.bar('continents','Number of applicants',data=continent_df)
plt.title('Bar Chart')
plt.xlabel('continent')
plt.ylabel('number of applicants')
plt.show()

# %%
continent_df
# Out:
#       continents  Number of applicants
# 0           Asia                 16861
# 1         Africa                   551
# 2  North America                  3292
# 3         Europe                  3732
# 4  South America                   852
# 5        Oceania                   192

# %% [markdown]
# **BAR CHART USING SEABORN**
# - we can plot bar chart using with many packages
# - one package is matplotlib
# - another package is seaborn
# - in matplotlib the method is **plt.bar**
# - in seaborn the method is **countplot**
# - in matplotlib
#    - we take the raw data
#    - we will create our frequency table i.e dataframe
#    - we will pass the column1,column2 and dataframe name
# - in seaborn count plot
#    - it take direct raw data
#    - we will provide column name
#    - we will provide main dataframe name

# %%
# continent column ==== continent_df====plt.bar
# continent column directly === visadf
import seaborn as sns
plt.figure(figsize=(8,5))
plt.title("bar chart")
plt.xlabel('continents')
plt.ylabel('number of applicants')

order_continent=['Asia','Europe','North America','South America','Africa','Ocenia']

sns.countplot(data=visa_df,x='continent',order=order_continent,color='red')
plt.savefig('continents_bar_chart_using_seaborn.jpg')
plt.show()

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
plt.title("bar chart")
plt.xlabel('continents')
plt.ylabel('number of applicants')

order_continent=visa_df['continent'].value_counts().keys()

sns.countplot(data=visa_df,x='continent',order=order_continent,color='red')
plt.savefig('continents_bar_chart_using_seaborn.jpg')
plt.show()

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
visa_df['education_of_employee'].nunique()
# Out:
# 4

# %%
for i in visa_df['education_of_employee'].unique():
    con=visa_df['education_of_employee']==i
    coun=len(visa_df[con])
    print(f'the number of applicants from {i} is: {coun}')
# Out:
# the number of applicants from High School is: 3420
# the number of applicants from Master's is: 9634
# the number of applicants from Bachelor's is: 10234
# the number of applicants from Doctorate is: 2192

# %%
education_df=visa_df['education_of_employee'].value_counts()
keys=education_df.keys()
values=education_df.values
cols=['labels','count']
df2=pd.DataFrame(zip(keys,values),columns=cols)
df2.to_csv('education1.csv',index=False)

# %%
ed_df=pd.read_csv('education1.csv')
ed_df
# Out:
#         labels  count
# 0   Bachelor's  10234
# 1     Master's   9634
# 2  High School   3420
# 3    Doctorate   2192

# %%
import matplotlib.pyplot as plt
plt.bar('labels','count',data=ed_df)
plt.title('Bar Chart')
plt.xlabel('Education')
plt.ylabel('Number of employee')
# Out:
# Text(0, 0.5, 'Number of employee')

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
plt.title('Bar Chart')
plt.xlabel('education')
plt.ylabel('number of employee')
order_ed=visa_df['education_of_employee'].value_counts().keys()
sns.countplot(data=visa_df,x='education_of_employee',order=order_ed)
plt.savefig('education_visa_df_bar_chart.jpg')
plt.show()

# %%
visa_df['education_of_employee'].value_counts().keys()
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object')

# %% [markdown]
# $Task-3$
#
# **using for loop plot the bar chart of all catogorical columns**
#
#
# - we can use seaborn and matplotlib
#
# - seaborn: countplot requires raw data , direct column name and main data
#
# - matplotlib : requires freuency tabl
#     - from raw data will make value counts
#     - from value counts we are making keys and values separtely
#     - then we are creating dataframe
#
# - start with seaborn
#     - then we require cat columns
#     - and main data frame
#
# - start with matplotlib
#     - we already created  a folder in our laptop : value_counts_df

# %%
import seaborn as sns
plt.figure(figsize=(8,5))
plt.title("bar chart")

order_continent=visa_df[i].value_counts().keys()

sns.countplot(data=visa_df,x='continent',order=order_continent,color='red')
plt.savefig('continents_bar_chart_using_seaborn.jpg')
plt.show()

# %%
cat_list
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#how to  create a folder
import os 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Documents\\naresh it\\EDA'

# %% [markdown]
# **os.makedirs()**
# - amkedirs create a leaf directory
# - means it will take  the current working directory and creates one extra folder
# - here my python file is in EDA folder
# - now i want to create called **graph_seaborn**
# - which is one step ahead of EDA folder : eda/draphs
#
# - pass the full inside the makedirs()

# %%
#step1: 
root_directory = os.getcwd()
root_directory

#step2
new_folder="graph_matplotlib"

#step3
new_dir=os.path.join(root_directory,new_folder)
new_dir

#step4
os.makedirs(new_dir)

# %%
import seaborn as ans 
for i in cat_list[1:]:
    plt.figure(figsize=(10,5))
    order_continent = visa_df[i].value_counts().keys()
    sns.countplot(data=visa_df,x=i,order=order_continent)
    plt.savefig(f"{new_dir}\\{i}_seaborn.jpg")
    plt.show()

# %%
new_dir
# Out:
# 'C:\\Users\\user\\Documents\\naresh it\\EDA\\graph_matplotlib'

# %%
#step1: 
root_directory = os.getcwd()
root_directory

#step2
new_folder="graph_matplotlib"

#step3
new_dir1=os.path.join(root_directory,new_folder)
new_dir

#step4
os.makedirs(new_dir1)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[25], line 13
#      10 new_dir
#      12 #step4
# ---> 13 os.makedirs(new_dir1)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\user\\Documents\\naresh it\\EDA\\graph_matplotlib'

# %%
root_directory = os.getcwd()

folder="graph_matplotlib"

new=os.path.join(root_directory,folder)
new
# Out:
# 'C:\\Users\\user\\Documents\\naresh it\\EDA\\graph_matplotlib'

# %%
dfs=os.listdir(new)
dfs
# Out:
# ['case_status.csv',
#  'continent.csv',
#  'education_of_employee.csv',
#  'full_time_position.csv',
#  'has_job_experience.csv',
#  'region_of_employment.csv',
#  'requires_job_training.csv',
#  'unit_of_wage.csv']

# %% [markdown]
# $task-4$
# **matplotlib**

# %%
import matplotlib.pyplot as plt
for i in dfs :
    df=pd.read_csv(i)
    plt.bar('labels','count',data=df)
    plt.title('Bar Chart')
    plt.xlabel('labels')
    plt.ylabel('count')
    plt.savefig(f"{new}\\{i}_matplotlib.jpg")
    plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar('labels','count',width = 2 ,data=ed_df,)
plt.title('Bar Chart')
plt.xlabel('Education')
plt.ylabel('Number of employee')

# %%
import matplotlib.pyplot as plt
plt.bar('labels','count',width=0.5,
        data=ed_df)
plt.title('Bar Chart')
plt.xlabel('Education')
plt.ylabel('Number of employee')
plt.show()

# %% [markdown]
# **SUB-PLOTS**

# %%
- If we have multiple plots when we apply for loop it is giving one by one
- it is hard to see all the graphs 
- subplots is a kind of atrix representation 
- supoose we have a 2x2 matrix means 4 values , means we can plot 
- first plot position represents with (2,2,1)
- second plot position represents with (2,2,2)
- third plot position represents with (2,2,3)
- four plot position represents with (2,2,4)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,9):
    plt.subplot(3,3,i)

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)

sns.countplot(data=visa_df,x='continent',width = 0.5)
plt.subplot(1,2,2)
sns.countplot(data=visa_df,x='case_status')
# Out:
# <Axes: xlabel='case_status', ylabel='count'>

# %%
cat_list
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=cat_list[1:]
for i in range(len(cols)):
    plt.figure(figsize=(20,14))
    plt.subplot(3,3,i+1)
    sns.countplot(data=visa_df,x=cols[i])

# %% [markdown]
# **method-3**

# %%
visa_df=pd.read_csv(path)

# %%
cat_list=visa_df.select_dtypes(include='object').columns
num_list=visa_df.select_dtypes(exclude='object').columns
cat_list
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
val_count=cat_list.value_counts()
val_count
# Out:
# case_id                  1
# continent                1
# education_of_employee    1
# has_job_experience       1
# requires_job_training    1
# region_of_employment     1
# unit_of_wage             1
# full_time_position       1
# case_status              1
# dtype: int64

# %%
c_df=visa_df['continent'].value_counts()
ax=c_df.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %%
ED_df=visa_df['education_of_employee'].value_counts()
ax=ED_df.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# **PIE CHART**

# %% [markdown]
# - PIE chart is a 360 degree view
# - it is matplotlib package
# - it will take key and values
# - that will get fro value counts

# %%
c_df_key=visa_df['continent'].value_counts().keys()
c_df_key
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
c_df_values=visa_df['continent'].value_counts().values
c_df_values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
plt.pie(c_df_values,explode=[0.10,0.10,0.10,0.10,0.10,0.10],
        labels=c_df_key,autopct="%0.2f%%",radius=2,
       startangle=90)
plt.show()
