# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 


path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df



cat_list=visa_df.select_dtypes(include='object').columns
num_list=visa_df.select_dtypes(exclude='object').columns
num_list
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **encoding**
#
# - encoding means covert catogorical culumns data to numerical data
# - coz ML MODEL expect the data should be in numerical format
# - ML models developed by math algorthm
# - it is very very important to applly encoding
# - the following mwthods are
#     - map
#     - np.where
#     - one hot encoding
#     - label encoder
#     -

# %% [markdown]
# **map method**
#
# - mapping is one method to covert catogorical values to numerical
# - take one categorical column
# - grt the unique labl first
# - make a dictionary with assign a number to each label
# - for example case_status has two labels
#      - certified
#      - denied
# - assign xero to certified , 1 to denied
# - labels as keys and values as values only
# - {'certified':0,'denied':1}
# -

# %%
un_cs=visa_df['case_status'].unique()
un_cs
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status_new']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# i want to aplly map methid to all cat columns 
# step-1: we need to get unique lables 
# step-2: we need to get a numbers = len unique lables
#step-3: we need to create a dictionary

# %%
list1=[i for i in range (len(un_cs))]
un_cs,list1
# Out:
# (array(['Denied', 'Certified'], dtype=object), [0, 1])

# %%
un_cs.sort()
un_cs
# Out:
# array(['Certified', 'Denied'], dtype=object)

# %%
dict1=dict(zip(un_cs,list1))
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
{key:value for key,value in zip(un_cs,list1)}
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
visa_df['case_status']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df[['case_status']]
# Out:
#        case_status
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 25475          NaN
# 25476          NaN
# 25477          NaN
# 25478          NaN
# 25479          NaN
#
# [25480 rows x 1 columns]

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 


path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df



cat_list=visa_df.select_dtypes(include='object').columns
num_list=visa_df.select_dtypes(exclude='object').columns
num_list
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df['case_status']=visa_df['case_status'].map(dict1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df

cat_list=visa_df.select_dtypes(include='object').columns
for i in cat_list:
    unique_labels=sorted(visa_df[i].unique())
    list1=[i for i in range (len(unique_labels))]
    dict1=dict(zip(un_cs,list1))
    dict1
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0        NaN                    NaN                 NaN
# 1            1        NaN                    NaN                 NaN
# 2            2        NaN                    NaN                 NaN
# 3            3        NaN                    NaN                 NaN
# 4            4        NaN                    NaN                 NaN
# ...        ...        ...                    ...                 ...
# 25475    17204        NaN                    NaN                 NaN
# 25476    17205        NaN                    NaN                 NaN
# 25477    17206        NaN                    NaN                 NaN
# 25478    17207        NaN                    NaN                 NaN
# 25479    17209        NaN                    NaN                 NaN
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                        NaN            14513         2007
# ...

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_list=visa_df.select_dtypes(include='object').columns
for i in cat_list:
    unique_labels=sorted(visa_df[i].unique())
    list1=[i for i in range (len(unique_labels))]
    dict1=dict(zip(un_cs,list1))
    dict1
    visa_df[i]=visa_df[i].map(dict1)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0        NaN                    NaN                 NaN
# 1            1        NaN                    NaN                 NaN
# 2            2        NaN                    NaN                 NaN
# 3            3        NaN                    NaN                 NaN
# 4            4        NaN                    NaN                 NaN
# ...        ...        ...                    ...                 ...
# 25475    17204        NaN                    NaN                 NaN
# 25476    17205        NaN                    NaN                 NaN
# 25477    17206        NaN                    NaN                 NaN
# 25478    17207        NaN                    NaN                 NaN
# 25479    17209        NaN                    NaN                 NaN
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                        NaN            14513         2007
# ...

# %% [markdown]
# **label encoder**
# - label encoder is a method to convert catogorical data to numerica data
# - label encoder is a same way , how we did above
# - the for loop method we expored
# - but the labelencoder also do the same
# - it is under **sickit-learn** we usually called as **sklearn**
# - under sk learn we have class caled  preprocessing
# - beacuse currently we are doing data preprocessing only
# - under preprocessing class we have method called as **label encoder**
# - sklearn
#     - preprocessing
#         - label encoder
#
#
#  - any sklearn package has 3 steps
#      - step1: read the package
#      - step2: save the package
#      - step3: apply the fit transform on data

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# step-1: read the package 
from sklearn.preprocessing import LabelEncoder
# step-2: save the package / call the method 
le=LabelEncoder() 
# step-3: apply fit transform on data 
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# step-1: read the package 
from sklearn.preprocessing import LabelEncoder
# step-2: save the package / call the method 
le=LabelEncoder() 
# step-3: apply fit transform on data
for i in cat_list:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform**
#
# - generally fit means develop the application
# - transform means process the logic
# - if we observe in map method first we developed dictionary logic
# - then we apply that dictionar to column
# - developing the dictionary is kind of fit
# - aplly the dictionary means to columns means we are transforming the data cat to num columns
# - whenevr we are transforming or changing the data then **fit transform**
# - if we are not changing the data then only fit **fit**

# %% [markdown]
# **np-where**
#
# - using np.where also we can change the categorical data to numerical
# - but np.where is only for binary condition
# - np.where is like if and else
# - if condition is true : we will aplly True value
# - if condition is False : we apply the False value
# - so np.where use for only binary labels
# - a column should have only two unique labels

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df['case_status']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int32

# %%
path=r"C:\Users\user\Documents\naresh it\data files\Visadataset.csv"

visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **one heart encoder**
#
# - one heart means one will be on another will be oFF
# - ON represents with 1
# - OFF represents with 0
# - for example cas estatus has 2 values
#     - certified
#     - denied
# - one heart encoder creates a new columns whixh is eual to number of unique labes
# - for example xase status wil create two new extra columns
#     - case_status_certified
#     - case_status_denied
#     |case_status|case_ceritifided|case_denied|
#     |-|-|-|
#     |denied|0|1|
#     |ceritified|1|0|
